# %%
# %matplotlib notebook

# %%
# !nvidia-smi
# Out:
# Thu Jul  2 11:47:47 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 440.64.00    CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN V             Off  | 00000000:03:00.0 Off |                  N/A |
# | 28%   32C    P8    23W / 250W |     12MiB / 12066MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla P100-PCIE...  Off  | 00000000:83:00.0 Off |                    0 |
# | N/A   32C    P0    27W / 250W |     10MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  TITAN V             Off  | 00000000:84:00.0 Off |                  N/A |
# | 30%   44C    P2    40W / 250W |   5810MiB / 12066MiB |     25%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    2      5477      C   ../../build/christoph_model/FinalFit1       3957MiB |
# |    2     42813      C   ...a/conda/envs/goofit-june2020/bin/python  1841MiB |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import torch
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd

import mlflow

from model.collectdata_mdsA import collect_data
from model.alt_loss_A import Loss
from model.training import trainNet, select_gpu
from model.model_29June2020_B import UNet4SC as Model
from model.training import trainNet, select_gpu, Results
from model.utilities import load_full_state, count_parameters
from model.plots import dual_train_plots, replace_in_ax
from model.utilities import count_parameters, Params
import hiddenlayer as HL
from torchsummary import summary

# %%
device = torch.device('cuda:0')    
mlflow.tracking.set_tracking_uri('file:/share/lazy/pv-finder_model_repo')
mlflow.set_experiment('Weird U-Net')

# %%
train_loader = collect_data('/share/lazy/sokoloff/ML-data_AA/Aug14_80K_train.h5',
                            '/share/lazy/sokoloff/ML-data_AA/Oct03_80K_train.h5',
                            '/share/lazy/sokoloff/ML-data_AA/Oct03_40K_train.h5',
                            '/share/lazy/will/ML/June30_2020_80k_1.h5',
##                            'dataAA/Oct03_80K2_train.h5',
                             batch_size=64,
                            masking=True, shuffle=True,
                            load_XandXsq=False,
                            load_xy=False)

val_loader = collect_data('/share/lazy/sokoloff/ML-data_AA/Oct03_20K_val.h5',
                          batch_size=64,
                          slice=slice(256 * 39),
                          device=device,
                          masking=True, shuffle=False,
                          load_XandXsq=False,
                          load_xy=False)
# Out:
# Loading data...
# Loaded /share/lazy/sokoloff/ML-data_AA/Aug14_80K_train.h5 in 13.47 s
# Loaded /share/lazy/sokoloff/ML-data_AA/Oct03_80K_train.h5 in 15.66 s
# Loaded /share/lazy/sokoloff/ML-data_AA/Oct03_40K_train.h5 in 7.529 s
# Loaded /share/lazy/will/ML/June30_2020_80k_1.h5 in 15.51 s
# Constructing 280000 event dataset took 1.635 s
# Loading data...
# Loaded /share/lazy/sokoloff/ML-data_AA/Oct03_20K_val.h5 in 3.752 s
# Constructing 9984 event dataset took 3.089 s

# %%
# %%writefile architecture.txt
# '''
# UNet model with the following properties:
# - 4 skip connections
# - 1/2 downsample rate
# **- No MaxPool layers; all downsampling occurs in the convolutional layers** (i.e. stride=2)
# - Kernel size decay (i.e. kernel size in convolutional layers proportionally decreases with downsampling)
# '''
# class ConvBNrelu(nn.Sequential):
#     """convolution => [BN] => ReLU"""
#     def __init__(self, in_channels, out_channels, k_size):
#         super(ConvBNrelu, self).__init__(
#             nn.Conv1d(in_channels, out_channels, k_size, stride=2, padding=(k_size-2)//2),
#             nn.BatchNorm1d(out_channels),
#             nn.ReLU())
#
# class ConvBNreluSame(nn.Sequential):
#     """preserves dimension of input"""
#     def __init__(self, in_channels, out_channels, k_size):
#         super(ConvBNreluSame, self).__init__(
#             nn.Conv1d(in_channels, out_channels, k_size, stride=1, padding=(k_size-1)//2),
#             nn.BatchNorm1d(out_channels),
#             nn.ReLU())
#
# class Up(nn.Sequential):
#     def __init__(self, inc, outc, k_size):
#         super().__init__(
#             nn.ConvTranspose1d(inc, outc, kernel_size=2, stride=2),
#             nn.Conv1d(outc, outc, k_size, stride=1, padding=(k_size-1)//2),
#             nn.BatchNorm1d(outc),
#             nn.ReLU())
#
#
# class UNet4SC(nn.Module):
#     def __init__(self, n=24):
#         super(UNet4SC, self).__init__()
#
#         self.rcbn1 = ConvBNreluSame(1, n, k_size=25)
#         self.rcbn2 = ConvBNrelu(n, n, k_size=12)
#         self.rcbn3 = ConvBNrelu(n, n, k_size=6)
#         self.rcbn4 = ConvBNrelu(n, n, k_size=4)
#         self.rcbn5 = ConvBNrelu(n, n, k_size=4)
#
#         self.up1 = Up(n, n, k_size=3)
#         self.up2 = Up(n*2, n, k_size=3)
#         self.up2 = Up(n*2, n, k_size=7)
#         self.up3 = Up(n*2, n, k_size=13)
#         self.up4 = Up(n*2, n, k_size=25)
#         self.outc = nn.Conv1d(n*2, 1, 3, padding=1)
#
#     def forward(self, x):
#
#         x1 = self.rcbn1(x) # 4000
#         x2 = self.rcbn2(x1) # 2000
#         x3 = self.rcbn3(x2) # 1000
#         x4 = self.rcbn4(x3) # 500
#         x = self.rcbn5(x4) # 250
#
#         x = self.up1(x) # 500
#         x = self.up2(torch.cat([x, x4], 1)) # 1000
#         x = self.up3(torch.cat([x, x3], 1)) #2000
#         x = self.up4(torch.cat([x, x2], 1)) #4000
#
#         logits_x0 = self.outc(torch.cat([x, x1], 1))
#
#         ret = torch.nn.Softplus()(logits_x0).squeeze()
#         return  ret
# Out:
# Overwriting architecture.txt

# %%
# params order - batch size, epochs, lr
runs = [
    #(Model(24).to(device), Params(64, 200, 5e-4, 0)),
    #(Model(16).to(device), Params(64, 200, 5e-4, 0)),
    #(Model(12).to(device), Params(64, 200, 5e-4, 0)),
    #(Model(24).to(device), Params(64, 200, 5e-3, 0)),
    #(Model(16).to(device), Params(64, 200, 5e-3, 0)),
    (Model(12).to(device), Params(64, 200, 5e-3, 0)),
    (Model(24).to(device), Params(64, 200, 1e-3, 0)),
    (Model(16).to(device), Params(64, 200, 1e-3, 0)),
    (Model(12).to(device), Params(64, 200, 1e-3, 0))
]

# %%
# Define optimizer and loss
loss = Loss(epsilon=1e-5,coefficient=2.5)
eff_avg = 0
fp_avg = 0

# %%
# we need this for plots
ax, tax, lax, lines = dual_train_plots()
fig = ax.figure
plt.tight_layout()
results = pd.DataFrame([], columns=Results._fields)

for (model, args) in runs:
    run_name = 'No MaxPool, kernel size decay'

    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    with mlflow.start_run(run_name = run_name) as run:

        for key, value in vars(args).items():
            print(key, value)
            mlflow.log_param(key, value)

        mlflow.log_param('Parameters', count_parameters(model))
        

        for result in trainNet(model, optimizer, loss,
                                train_loader, val_loader,
                                args.epochs+args.epoch_start, epoch_start=args.epoch_start, notebook=False, device=device):

            result = result._asdict()
            
            # plotting code block ===============================
            results = results.append(pd.Series(result), ignore_index=True)
            xs = results.index
            # Update the plot above
            lines['train'].set_data(results.index,results.cost)
            lines['val'].set_data(results.index,results.val)
            #filter first cost epoch (can be really large)
            max_cost = max(max(results.cost if len(results.cost)<2 else results.cost[1:]), max(results.val))
            
            min_cost = min(min(results.cost), min(results.val))
            # The plot limits need updating too
            ax.set_ylim(min_cost*.9, max_cost*1.1)  
            ax.set_xlim(-.5, len(results.cost) - .5)
            replace_in_ax(lax, lines['eff'], xs, results['eff_val'].apply(lambda x: x.eff_rate))
            replace_in_ax(tax, lines['fp'], xs, results['eff_val'].apply(lambda x: x.fp_rate))
            # Redraw the figure
#            fig.canvas.draw()
            fig.savefig('plot.png')
            # plotting code block =============================== 

            # Log metrics
            mlflow.log_metric('Efficiency', result['eff_val'].eff_rate, result['epoch'])
            mlflow.log_metric('False Positive Rate',  result['eff_val'].fp_rate, result['epoch'])
            mlflow.log_metric('Validation Loss',  result['val']*2, result['epoch'])
            mlflow.log_metric('Training Loss',  result['cost']*2, result['epoch'])
            
            # Log tags
            mlflow.set_tag('Optimizer', 'Adam')
            mlflow.set_tag('Kernel size', 'Mixed')
            mlflow.set_tag('Skip connections', '4')
            mlflow.set_tag('Activation', 'Softplus')
            mlflow.set_tag('Mid Activation', 'Relu')

            # Save model AND optimizer state_dict AND epoch number. x
            torch.save({
                'model':model.state_dict(),
                'optimizer':optimizer.state_dict(),
                'epoch':args.epochs+result['epoch']
                }, 'run_stats.pyt')
            mlflow.log_artifact('run_stats.pyt')
            
            # save a diagram of the architecture
            HL.transforms.Fold("Conv > BatchNorm > LeakyRelu", "ConvBnRelu"),
            HL.build_graph(model, torch.zeros([args.batch_size, 1, 4000]).to(device)).save('architecture', format='png')
            mlflow.log_artifact('architecture.png')
        
            # log the code for the model architecture
            mlflow.log_artifact('architecture.txt')
        
            # save plot that mike likes
            mlflow.log_artifact('plot.png')
# Out:
# <div id='64580c50-b5d1-494d-96b7-aaea044474cd'></div>
# epoch_start 0
# batch_size 64
# epochs 200
# lr 0.005
# =============================== HYPERPARAMETERS ================================
# n_epochs: 200
# batch_size: 64 events
# dataset_train: 280000 events
# dataset_val: 9984 events
# loss: Loss()
# optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.005
#     weight_decay: 0
# )
# model: UNet4SC(
#   (rcbn1): ConvBNreluSame(
#     (0): Conv1d(1, 12, kernel_size=(25,), stride=(1,), padding=(12,))
#     (1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (rcbn2): ConvBNrelu(
#     (0): Conv1d(12, 12, kernel_size=(12,), stride=(2,), padding=(5,))
#     (1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (rcbn3): ConvBNrelu(
#     (0): Conv1d(12, 12, kernel_size=(6,), stride=(2,), padding=(2,))
#     (1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (rcbn4): ConvBNrelu(
#     (0): Conv1d(12, 12, kernel_size=(4,), stride=(2,), padding=(1,))
#     (1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (rcbn5): ConvBNrelu(
#     (0): Conv1d(12, 12, kernel_size=(4,), stride=(2,), padding=(1,))
#     (1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (up1): Up(
#     (0): ConvTranspose1d(12, 12, kernel_size=(2,), stride=(2,))
#     (1): Conv1d(12, 12, kernel_size=(3,), stride=(1,), padding=(1,))
#     (2): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#   )
#   (up2): Up(
#     (0): ConvTranspose1d(24, 12, kernel_size=(2,), stride=(2,))
#     (1): Conv1d(12, 12, kernel_size=(7,), stride=(1,), padding=(3,))
#     (2): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#   )
#   (up3): Up(
#     (0): ConvTranspose1d(24, 12, kernel_size=(2,), stride=(2,))
#     (1): Conv1d(12, 12, kernel_size=(13,), stride=(1,), padding=(6,))
#     (2): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#   )
#   (up4): Up(
#     (0): ConvTranspose1d(24, 12, kernel_size=(2,), stride=(2,))
#     (1): Conv1d(12, 12, kernel_size=(25,), stride=(1,), padding=(12,))
#     (2): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#   )
#   (outc): Conv1d(24, 1, kernel_size=(3,), stride=(1,), padding=(1,))
# )
# ================================================================================
# Number of batches: train = 4375, val = 156
# Epoch 0: train=9.05933, val=4.14206, took 94.765 s
#   Validation Found 50930 of 54504, added 2561 (eff 93.44%) (0.256 FP/event)
# Epoch 1: train=3.93574, val=4.04882, took 90.147 s
#   Validation Found 50847 of 54504, added 2029 (eff 93.29%) (0.203 FP/event)
# Epoch 2: train=3.85576, val=3.9987, took 90.915 s
#   Validation Found 50410 of 54504, added 1335 (eff 92.49%) (0.134 FP/event)
# Epoch 3: train=3.81504, val=4.01746, took 88.415 s
#   Validation Found 50567 of 54504, added 1643 (eff 92.78%) (0.165 FP/event)
# Epoch 4: train=3.79035, val=3.75448, took 88.315 s
#   Validation Found 51304 of 54504, added 1930 (eff 94.13%) (0.193 FP/event)
# Epoch 5: train=3.76691, val=3.78168, took 90.178 s
#   Validation Found 51203 of 54504, added 1886 (eff 93.94%) (0.189 FP/event)
# Epoch 6: train=3.75526, val=3.76112, took 90.057 s
#   Validation Found 51279 of 54504, added 1853 (eff 94.08%) (0.186 FP/event)
# Epoch 7: train=3.74019, val=3.79806, took 88.855 s
#   Validation Found 51024 of 54504, added 1626 (eff 93.62%) (0.163 FP/event)
# Epoch 8: train=3.7298, val=3.71869, took 90.836 s
#   Validation Found 51362 of 54504, added 1962 (eff 94.24%) (0.196 FP/event)
# Epoch 9: train=3.71712, val=3.71064, took 90.202 s
#   Validation Found 51286 of 54504, added 1790 (eff 94.10%) (0.179 FP/event)
# Epoch 10: train=3.70714, val=3.75492, took 88.955 s
#   Validation Found 51181 of 54504, added 1636 (eff 93.90%) (0.164 FP/event)
# Epoch 11: train=3.70098, val=3.68631, took 88.108 s
#   Validation Found 51336 of 54504, added 1798 (eff 94.19%) (0.18 FP/event)
# Epoch 12: train=3.69418, val=3.87168, took 88.749 s
#   Validation Found 50844 of 54504, added 1295 (eff 93.28%) (0.13 FP/event)
# Epoch 13: train=3.69046, val=3.65538, took 89.001 s
#   Validation Found 51542 of 54504, added 2072 (eff 94.57%) (0.208 FP/event)
# Epoch 14: train=3.68349, val=3.65587, took 88.126 s
#   Validation Found 51496 of 54504, added 2044 (eff 94.48%) (0.205 FP/event)
# Epoch 15: train=3.67966, val=3.66536, took 90.469 s
#   Validation Found 51355 of 54504, added 1781 (eff 94.22%) (0.178 FP/event)
# Epoch 16: train=3.67622, val=3.6728, took 88.325 s
#   Validation Found 51506 of 54504, added 1888 (eff 94.50%) (0.189 FP/event)
# Epoch 17: train=3.67098, val=3.73268, took 89.759 s
#   Validation Found 51592 of 54504, added 2274 (eff 94.66%) (0.228 FP/event)
# Epoch 18: train=3.66828, val=3.6664, took 89.869 s
#   Validation Found 51329 of 54504, added 1675 (eff 94.17%) (0.168 FP/event)
# Epoch 19: train=3.66653, val=3.65331, took 89.151 s
#   Validation Found 51429 of 54504, added 1803 (eff 94.36%) (0.181 FP/event)
# Epoch 20: train=3.66327, val=3.66604, took 90.263 s
#   Validation Found 51563 of 54504, added 1911 (eff 94.60%) (0.191 FP/event)
# Epoch 21: train=3.66082, val=3.63925, took 90.485 s
#   Validation Found 51595 of 54504, added 2043 (eff 94.66%) (0.205 FP/event)
# Epoch 22: train=3.65916, val=3.66676, took 89.524 s
#   Validation Found 51386 of 54504, added 1628 (eff 94.28%) (0.163 FP/event)
# Epoch 23: train=3.65396, val=3.61756, took 91.08 s
#   Validation Found 51637 of 54504, added 2011 (eff 94.74%) (0.201 FP/event)
# Epoch 24: train=3.65358, val=3.66005, took 91.172 s
#   Validation Found 51369 of 54504, added 1687 (eff 94.25%) (0.169 FP/event)
# Epoch 25: train=3.65063, val=3.63773, took 91.874 s
#   Validation Found 51474 of 54504, added 1736 (eff 94.44%) (0.174 FP/event)
# Epoch 26: train=3.64843, val=3.62041, took 92.115 s
#   Validation Found 51592 of 54504, added 1921 (eff 94.66%) (0.192 FP/event)
# Epoch 27: train=3.64604, val=3.61746, took 87.818 s
#   Validation Found 51514 of 54504, added 1782 (eff 94.51%) (0.178 FP/event)
# Epoch 28: train=3.6459, val=3.61836, took 91.865 s
#   Validation Found 51570 of 54504, added 1895 (eff 94.62%) (0.19 FP/event)
# Epoch 29: train=3.64459, val=3.66262, took 90.49 s
#   Validation Found 51433 of 54504, added 1732 (eff 94.37%) (0.173 FP/event)
# Epoch 30: train=3.64143, val=3.62033, took 90.237 s
#   Validation Found 51635 of 54504, added 1922 (eff 94.74%) (0.192 FP/event)
# Epoch 31: train=3.63876, val=3.64926, took 90.036 s
#   Validation Found 51486 of 54504, added 1866 (eff 94.46%) (0.187 FP/event)
# Epoch 32: train=3.63773, val=3.60391, took 88.052 s
#   Validation Found 51514 of 54504, added 1797 (eff 94.51%) (0.18 FP/event)
# Epoch 33: train=3.63709, val=3.59393, took 90.818 s
#   Validation Found 51570 of 54504, added 1799 (eff 94.62%) (0.18 FP/event)
# Epoch 34: train=3.63609, val=3.61194, took 92.59 s
#   Validation Found 51605 of 54504, added 1873 (eff 94.68%) (0.188 FP/event)
# Epoch 35: train=3.63495, val=3.59959, took 87.932 s
#   Validation Found 51658 of 54504, added 1955 (eff 94.78%) (0.196 FP/event)
# Epoch 36: train=3.6335, val=3.61592, took 91.863 s
#   Validation Found 51702 of 54504, added 2124 (eff 94.86%) (0.213 FP/event)
# Epoch 37: train=3.63136, val=3.61357, took 90.623 s
#   Validation Found 51635 of 54504, added 1915 (eff 94.74%) (0.192 FP/event)
# Epoch 38: train=3.63115, val=3.66804, took 93.361 s
#   Validation Found 51312 of 54504, added 1552 (eff 94.14%) (0.155 FP/event)
# Epoch 39: train=3.62841, val=3.64358, took 90.231 s
#   Validation Found 51458 of 54504, added 1733 (eff 94.41%) (0.174 FP/event)
# Epoch 40: train=3.62695, val=3.59355, took 88.034 s
#   Validation Found 51568 of 54504, added 1795 (eff 94.61%) (0.18 FP/event)
# Epoch 41: train=3.62849, val=3.61041, took 89.0 s
#   Validation Found 51575 of 54504, added 1788 (eff 94.63%) (0.179 FP/event)
# Epoch 42: train=3.62787, val=3.59484, took 88.294 s
#   Validation Found 51634 of 54504, added 1914 (eff 94.73%) (0.192 FP/event)
# Epoch 43: train=3.62684, val=3.59867, took 87.99 s
#   Validation Found 51686 of 54504, added 2075 (eff 94.83%) (0.208 FP/event)
# Epoch 44: train=3.6238, val=3.57207, took 92.591 s
#   Validation Found 51744 of 54504, added 2088 (eff 94.94%) (0.209 FP/event)
# Epoch 45: train=3.62309, val=3.59774, took 89.894 s
#   Validation Found 51543 of 54504, added 1866 (eff 94.57%) (0.187 FP/event)
# Epoch 46: train=3.62201, val=3.59711, took 91.453 s
#   Validation Found 51587 of 54504, added 1824 (eff 94.65%) (0.183 FP/event)
# Epoch 47: train=3.62047, val=3.57918, took 88.866 s
#   Validation Found 51651 of 54504, added 1947 (eff 94.77%) (0.195 FP/event)
# Epoch 48: train=3.6217, val=3.69371, took 90.499 s
#   Validation Found 51583 of 54504, added 1971 (eff 94.64%) (0.197 FP/event)
# Epoch 49: train=3.61923, val=3.61739, took 89.331 s
#   Validation Found 51691 of 54504, added 2123 (eff 94.84%) (0.213 FP/event)
# Epoch 50: train=3.61882, val=3.61514, took 90.761 s
#   Validation Found 51737 of 54504, added 2108 (eff 94.92%) (0.211 FP/event)
# Epoch 51: train=3.61728, val=3.63046, took 91.314 s
#   Validation Found 51630 of 54504, added 1913 (eff 94.73%) (0.192 FP/event)
# Epoch 52: train=3.61575, val=3.63496, took 88.224 s
#   Validation Found 51622 of 54504, added 1829 (eff 94.71%) (0.183 FP/event)
# Epoch 53: train=3.61673, val=3.67586, took 89.765 s
#   Validation Found 51428 of 54504, added 1682 (eff 94.36%) (0.168 FP/event)
# Epoch 54: train=3.61282, val=3.60563, took 90.896 s
#   Validation Found 51740 of 54504, added 2079 (eff 94.93%) (0.208 FP/event)
# Epoch 55: train=3.61301, val=3.64118, took 88.587 s
#   Validation Found 51461 of 54504, added 1679 (eff 94.42%) (0.168 FP/event)
# Epoch 56: train=3.61242, val=3.63974, took 91.352 s
#   Validation Found 51446 of 54504, added 1732 (eff 94.39%) (0.173 FP/event)
# Epoch 57: train=3.61163, val=3.62521, took 91.515 s
#   Validation Found 51580 of 54504, added 1848 (eff 94.64%) (0.185 FP/event)
# Epoch 58: train=3.60923, val=3.57737, took 89.001 s
#   Validation Found 51650 of 54504, added 1859 (eff 94.76%) (0.186 FP/event)
# Epoch 59: train=3.61122, val=3.6156, took 88.395 s
#   Validation Found 51377 of 54504, added 1625 (eff 94.26%) (0.163 FP/event)
# Epoch 60: train=3.60987, val=3.57995, took 89.044 s
#   Validation Found 51637 of 54504, added 1888 (eff 94.74%) (0.189 FP/event)
# Epoch 61: train=3.6084, val=3.64082, took 91.638 s
#   Validation Found 51433 of 54504, added 1620 (eff 94.37%) (0.162 FP/event)
# Epoch 62: train=3.60755, val=3.59279, took 89.255 s
#   Validation Found 51521 of 54504, added 1754 (eff 94.53%) (0.176 FP/event)
# Epoch 63: train=3.60771, val=3.59709, took 88.89 s
#   Validation Found 51647 of 54504, added 1863 (eff 94.76%) (0.187 FP/event)
# Epoch 64: train=3.60752, val=3.5767, took 88.531 s
#   Validation Found 51636 of 54504, added 1923 (eff 94.74%) (0.193 FP/event)
# Epoch 65: train=3.60664, val=3.59485, took 88.673 s
#   Validation Found 51609 of 54504, added 1884 (eff 94.69%) (0.189 FP/event)
# Epoch 66: train=3.60613, val=3.57492, took 88.328 s
#   Validation Found 51654 of 54504, added 1975 (eff 94.77%) (0.198 FP/event)
# Epoch 67: train=3.60465, val=3.57142, took 88.162 s
#   Validation Found 51661 of 54504, added 1857 (eff 94.78%) (0.186 FP/event)
# Epoch 68: train=3.60457, val=3.58871, took 89.549 s
#   Validation Found 51708 of 54504, added 1990 (eff 94.87%) (0.199 FP/event)
# Epoch 69: train=3.60305, val=3.57329, took 88.785 s
#   Validation Found 51648 of 54504, added 1946 (eff 94.76%) (0.195 FP/event)
# Epoch 70: train=3.60289, val=3.57003, took 88.802 s
#   Validation Found 51632 of 54504, added 1818 (eff 94.73%) (0.182 FP/event)
# Epoch 71: train=3.60166, val=3.57617, took 89.529 s
#   Validation Found 51610 of 54504, added 1826 (eff 94.69%) (0.183 FP/event)
# Epoch 72: train=3.60249, val=3.58131, took 90.384 s
#   Validation Found 51683 of 54504, added 1956 (eff 94.82%) (0.196 FP/event)
# Epoch 73: train=3.60472, val=3.57509, took 92.458 s
#   Validation Found 51685 of 54504, added 2003 (eff 94.83%) (0.201 FP/event)
# Epoch 74: train=3.60084, val=3.56884, took 91.085 s
#   Validation Found 51791 of 54504, added 2126 (eff 95.02%) (0.213 FP/event)
# Epoch 75: train=3.60014, val=3.58009, took 88.696 s
#   Validation Found 51738 of 54504, added 2060 (eff 94.93%) (0.206 FP/event)
# Epoch 76: train=3.59923, val=3.60324, took 89.204 s
#   Validation Found 51574 of 54504, added 1767 (eff 94.62%) (0.177 FP/event)
# Epoch 77: train=3.59873, val=3.55631, took 88.678 s
#   Validation Found 51759 of 54504, added 1992 (eff 94.96%) (0.199 FP/event)
# Epoch 78: train=3.59883, val=3.589, took 89.617 s
#   Validation Found 51506 of 54504, added 1644 (eff 94.50%) (0.165 FP/event)
# Epoch 79: train=3.59859, val=3.58562, took 89.412 s
#   Validation Found 51602 of 54504, added 1854 (eff 94.68%) (0.186 FP/event)
# Epoch 80: train=3.59868, val=3.56528, took 88.771 s
#   Validation Found 51658 of 54504, added 1843 (eff 94.78%) (0.185 FP/event)
# Epoch 81: train=3.59602, val=3.57583, took 91.627 s
#   Validation Found 51573 of 54504, added 1802 (eff 94.62%) (0.18 FP/event)
# Epoch 82: train=3.59702, val=3.56519, took 91.942 s
#   Validation Found 51656 of 54504, added 1933 (eff 94.77%) (0.194 FP/event)
# Epoch 83: train=3.59584, val=3.67486, took 89.447 s
#   Validation Found 51900 of 54504, added 2611 (eff 95.22%) (0.261 FP/event)
# Epoch 84: train=3.59598, val=3.55535, took 87.657 s
#   Validation Found 51677 of 54504, added 1926 (eff 94.81%) (0.193 FP/event)
# Epoch 85: train=3.59473, val=3.56901, took 87.931 s
#   Validation Found 51625 of 54504, added 1789 (eff 94.72%) (0.179 FP/event)
# Epoch 86: train=3.59664, val=3.57808, took 92.411 s
#   Validation Found 51726 of 54504, added 2042 (eff 94.90%) (0.205 FP/event)
# Epoch 87: train=3.59511, val=3.59105, took 90.817 s
#   Validation Found 51513 of 54504, added 1694 (eff 94.51%) (0.17 FP/event)
# Epoch 88: train=3.59459, val=3.63, took 88.151 s
#   Validation Found 51528 of 54504, added 1850 (eff 94.54%) (0.185 FP/event)
# Epoch 89: train=3.59375, val=3.58248, took 88.489 s
#   Validation Found 51680 of 54504, added 1837 (eff 94.82%) (0.184 FP/event)
# Epoch 90: train=3.59453, val=3.61288, took 88.206 s
#   Validation Found 51609 of 54504, added 1794 (eff 94.69%) (0.18 FP/event)
# Epoch 91: train=3.59236, val=3.57715, took 87.041 s
#   Validation Found 51754 of 54504, added 2131 (eff 94.95%) (0.213 FP/event)
# Epoch 92: train=3.59307, val=3.59638, took 88.778 s
#   Validation Found 51639 of 54504, added 1858 (eff 94.74%) (0.186 FP/event)
# Epoch 93: train=3.59366, val=3.60294, took 88.57 s
#   Validation Found 51614 of 54504, added 1806 (eff 94.70%) (0.181 FP/event)
# Epoch 94: train=3.59144, val=3.57803, took 88.831 s
#   Validation Found 51610 of 54504, added 1780 (eff 94.69%) (0.178 FP/event)
# Epoch 95: train=3.593, val=3.5813, took 91.15 s
#   Validation Found 51681 of 54504, added 1906 (eff 94.82%) (0.191 FP/event)
# Epoch 96: train=3.59077, val=3.5867, took 88.399 s
#   Validation Found 51633 of 54504, added 1788 (eff 94.73%) (0.179 FP/event)
# Epoch 97: train=3.59069, val=3.58494, took 91.692 s
#   Validation Found 51599 of 54504, added 1765 (eff 94.67%) (0.177 FP/event)
# Epoch 98: train=3.5901, val=3.5762, took 87.676 s
#   Validation Found 51764 of 54504, added 2033 (eff 94.97%) (0.204 FP/event)
# Epoch 99: train=3.59026, val=3.56592, took 92.605 s
#   Validation Found 51723 of 54504, added 1976 (eff 94.90%) (0.198 FP/event)
# Epoch 100: train=3.59027, val=3.62596, took 87.753 s
#   Validation Found 51683 of 54504, added 2087 (eff 94.82%) (0.209 FP/event)
# Epoch 101: train=3.58784, val=3.56919, took 88.075 s
#   Validation Found 51719 of 54504, added 1980 (eff 94.89%) (0.198 FP/event)
# Epoch 102: train=3.58955, val=3.5619, took 90.036 s
#   Validation Found 51739 of 54504, added 1974 (eff 94.93%) (0.198 FP/event)
# Epoch 103: train=3.58675, val=3.57956, took 89.614 s
#   Validation Found 51655 of 54504, added 1824 (eff 94.77%) (0.183 FP/event)
# Epoch 104: train=3.58902, val=3.57352, took 89.963 s
#   Validation Found 51686 of 54504, added 1888 (eff 94.83%) (0.189 FP/event)
# Epoch 105: train=3.58679, val=3.5735, took 88.636 s
#   Validation Found 51643 of 54504, added 1842 (eff 94.75%) (0.184 FP/event)
# Epoch 106: train=3.58657, val=3.56736, took 89.898 s
#   Validation Found 51680 of 54504, added 1898 (eff 94.82%) (0.19 FP/event)
# Epoch 107: train=3.58656, val=3.5671, took 90.266 s
#   Validation Found 51713 of 54504, added 1992 (eff 94.88%) (0.199 FP/event)
# Epoch 108: train=3.58702, val=3.57236, took 89.664 s
#   Validation Found 51777 of 54504, added 2003 (eff 95.00%) (0.201 FP/event)

# %%
##quit()
